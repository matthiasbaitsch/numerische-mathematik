# %% [markdown]
# # Übungsblatt 2: Fachwerke erzeugen und zeichnen

# %%
# Existierende Pakete
import numpy as np
from objdict import *

# Eigener code
from truss import *
from structures import *

# Automatisch neu laden
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Drei Stäbe

# %%
s = simple_example()
draw_system(s)

# %% [markdown]
# ### Fachwerkträger

# %%
s = girder(40, 2, 7, 11)
draw_system(s)
