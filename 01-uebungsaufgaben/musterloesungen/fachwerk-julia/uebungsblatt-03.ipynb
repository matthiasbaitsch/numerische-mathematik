# %% [markdown]
# # Übungsblatt 3

# %%
using Revise
using DotMaps
using CairoMakie
using LinearAlgebra
using Makie.GeometryBasics

include("truss.jl")
include("structures.jl")
# Out:
# girder (generic function with 1 method)

# %% [markdown]
# ## Drei Stäbe

# %%
s = simple_example()
solve!(s)

draw_deformations(s)

# %%
draw_member_forces(s)

# %% [markdown]
# ## Fachwerk

# %%
s = girder(40, 2, 8, 11)
solve!(s)

draw_deformations(s)

# %%
draw_member_forces(s)
