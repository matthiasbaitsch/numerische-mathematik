# %% [markdown]
# # Übungsblatt 2

# %%
using Revise
using DotMaps
using CairoMakie
using LinearAlgebra

include("truss.jl")
include("structures.jl")
# Out:
# girder (generic function with 1 method)

# %% [markdown]
# ## Drei Stäbe

# %%
s = simple_example()
draw_system(s)

# %% [markdown]
# ## Fachwerk

# %%
s = girder(40, 5, 8, 11)
draw_system(s)
