# %% [markdown]
# # Numerische Lösung von Anfangswertproblemen

# %%
using CairoMakie

# %% [markdown]
# ## Testproblem

# %% [markdown]
# Anfangswertproblem

# %%
F(x, y) = sin(2π*x) + y
x0 = 0.0
y0 = 0.0;

# %% [markdown]
# Exakte Lösung

# %%
y(x) = (2π * exp(x) - sin(2π * x) - 2π * cos(2π * x)) / (1 + 4π^2)
xex = range(0, 2, step=0.01)
yex = y.(xex)
lines(xex, yex)
